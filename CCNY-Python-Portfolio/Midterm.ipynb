# %%
import pandas as pd

# %%
df = pd.read_csv("inaug_speeches.csv", encoding='windows-1252')
df = df.loc[:, ~df.columns.str.contains('^Unnamed')]
print(df)
# Out:
#                       Name         Inaugural Address  \
# 0        George Washington   First Inaugural Address
# 1        George Washington  Second Inaugural Address
# 2               John Adams         Inaugural Address
# 3         Thomas Jefferson   First Inaugural Address
# 4         Thomas Jefferson  Second Inaugural Address
# 5            James Madison   First Inaugural Address
# 6            James Madison  Second Inaugural Address
# 7             James Monroe   First Inaugural Address
# 8             James Monroe  Second Inaugural Address
# 9        John Quincy Adams         Inaugural Address
# 10          Andrew Jackson   First Inaugural Address
# 11          Andrew Jackson  Second Inaugural Address
# 12        Martin Van Buren         Inaugural Address
# 13  William Henry Harrison         Inaugural Address
# 14         James Knox Polk         Inaugural Address
# 15          Zachary Taylor         Inaugural Address
# 16         Franklin Pierce         Inaugural Address
# ...

# %%
df
# Out:
#                       Name         Inaugural Address  \
# 0        George Washington   First Inaugural Address
# 1        George Washington  Second Inaugural Address
# 2               John Adams         Inaugural Address
# 3         Thomas Jefferson   First Inaugural Address
# 4         Thomas Jefferson  Second Inaugural Address
# 5            James Madison   First Inaugural Address
# 6            James Madison  Second Inaugural Address
# 7             James Monroe   First Inaugural Address
# 8             James Monroe  Second Inaugural Address
# 9        John Quincy Adams         Inaugural Address
# 10          Andrew Jackson   First Inaugural Address
# 11          Andrew Jackson  Second Inaugural Address
# 12        Martin Van Buren         Inaugural Address
# 13  William Henry Harrison         Inaugural Address
# 14         James Knox Polk         Inaugural Address
# 15          Zachary Taylor         Inaugural Address
# 16         Franklin Pierce         Inaugural Address
# ...

# %%
no_cols = len(df.columns)
no_rows = len(df)

# %%
print(f'We have {no_cols} columns.')
print(f'We have {no_rows} rows.')
# Out:
# We have 4 columns.
# We have 58 rows.

# %%
df.columns
# Out:
# Index(['Name', 'Inaugural Address', 'Date', 'text'], dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 58 entries, 0 to 57
# Data columns (total 4 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Name               58 non-null     object
#  1   Inaugural Address  58 non-null     object
#  2   Date               58 non-null     object
#  3   text               58 non-null     object
# dtypes: object(4)
# memory usage: 1.9+ KB

# %%
df.describe(include='all')
# Out:
#                          Name  Inaugural Address                      Date  \
# count                      58                 58                        58
# unique                     39                  5                        58
# top     Franklin D. Roosevelt  Inaugural Address  Thursday, April 30, 1789
# freq                        4                 22                         1
#
#                                                      text
# count                                                  58
# unique                                                 58
# top                Fellow-Citizens of the Senate and o...
# freq                                                    1

# %%
name_freq = df['Name'].value_counts()

# %%
name_freq
# Out:
# Name
# Franklin D. Roosevelt     4
# George Washington         2
# Abraham Lincoln           2
# Barack Obama              2
# George W. Bush            2
# Bill Clinton              2
# Ronald Reagan             2
# Richard Milhous Nixon     2
# Dwight D. Eisenhower      2
# Woodrow Wilson            2
# Grover Cleveland          2
# Ulysses S. Grant          2
# William McKinley          2
# Thomas Jefferson          2
# James Madison             2
# James Monroe              2
# Andrew Jackson            2
# James Buchanan            1
# Franklin Pierce           1
# George Bush               1
# John Quincy Adams         1
# Jimmy Carter              1
# Lyndon Baines Johnson     1
# John F. Kennedy           1
# Martin Van Buren          1
# Harry S. Truman           1
# William Henry Harrison    1
# Herbert Hoover            1
# Calvin Coolidge           1
# Warren G. Harding         1
# James Knox Polk           1
# William Howard Taft       1
# Theodore Roosevelt        1
# ...

# %%
name_freq.plot(kind='bar')
# Out:
# <Axes: xlabel='Name'>

# %%
name_freq = df['Inaugural Address'].value_counts()
name_freq
# Out:
# Inaugural Address
# Inaugural Address           22
# First Inaugural Address     17
# Second Inaugural Address    17
# Third Inaugural Address      1
# Fourth Inaugural Address     1
# Name: count, dtype: int64

# %%
name_freq.plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
name_freq = df['Date'].value_counts()
name_freq
# Out:
# Date
# Thursday, April 30, 1789       1
# Friday, January 20, 1961       1
# Tuesday, March 4, 1913         1
# Monday, March 5, 1917          1
# Friday, March 4, 1921          1
# Wednesday, March 4, 1925       1
# Monday, March 4, 1929          1
# Saturday, March 4, 1933        1
# Wednesday, January 20, 1937    1
# Monday, January 20, 1941       1
# Saturday, January 20, 1945     1
# Thursday, January 20, 1949     1
# Tuesday, January 20, 1953      1
# Monday, January 21, 1957       1
# Wednesday, January 20, 1965    1
# Monday, March 4, 1793          1
# Monday, January 20, 1969       1
# Saturday, January 20, 1973     1
# Thursday, January 20, 1977     1
# Tuesday, January 20, 1981      1
# Monday, January 21, 1985       1
# Friday, January 20, 1989       1
# Wednesday, January 21, 1993    1
# January 20, 1997               1
# Saturday, January 20, 2001     1
# Thursday, January 20, 2005     1
# Tuesday, January 20, 2009      1
# Monday, January 21, 2013       1
# ...

# %%
name_freq.plot(kind='line')
# Out:
# <Axes: xlabel='Date'>

# %%
df['Date'] = pd.to_datetime(df['Date'])
filtered_df = df[df['Date'].dt.year >= 2000]
print(filtered_df)
# Out:
#                Name         Inaugural Address       Date  \
# 53   George W. Bush   First Inaugural Address 2001-01-20
# 54   George W. Bush  Second Inaugural Address 2005-01-20
# 55     Barack Obama   First Inaugural Address 2009-01-20
# 56     Barack Obama  Second Inaugural Address 2013-01-21
# 57  Donald J. Trump         Inaugural Address 2017-01-20
#
#                                                  text
# 53              President Clinton, distinguished g...
# 54              Vice President Cheney, Mr. Chief J...
# 55              My fellow citizens:      I stand h...
# 56              Vice President Biden, Mr. Chief Ju...
# 57             Chief Justice Roberts, President Ca...
